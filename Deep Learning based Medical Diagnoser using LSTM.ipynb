# %% [markdown]
# # Deep Learning based Medical Diagnoser

# %% [markdown]
# ## Introduction
#
# The rapid growth of Artificial Intelligence has opened new possibilities in the healthcare domain, especially in assisting medical diagnosis. With the help of Deep Learning, it is now possible to analyze patient symptoms and generate meaningful insights within seconds. Deep Learning models can automatically learn complex patterns from large volumes of data, making them highly effective for decision-support systems in medicine.
#
# This project focuses on developing an intelligent medical diagnosis system that predicts diseases and recommends appropriate medications based on a patient’s symptoms. Instead of relying on manual analysis, the system processes textual symptom descriptions and provides instant predictions using a trained deep learning model. Such AI-driven solutions can help improve efficiency, reduce diagnostic time, and support healthcare professionals in decision-making.

# %% [markdown]
# ## Project Description
#
# In this project, a Deep Learning–based medical diagnosis model is designed and implemented using TensorFlow. The model is trained on textual data representing patient symptoms and is capable of predicting both the disease and the corresponding medication as output.
#
# Since patient symptoms are provided in the form of text sequences, a Recurrent Neural Network (RNN) architecture is required to capture the contextual relationship between words. To achieve this, a Long Short-Term Memory (LSTM) network is used. LSTM models are well-known for their ability to remember important information from earlier parts of a sentence, making them suitable for understanding symptom progression and severity.
#
# For example, symptoms such as loss of appetite followed by fatigue and muscle weakness carry more meaning when their order is preserved. The LSTM layer effectively learns these sequential dependencies to improve prediction accuracy.
#
# The dataset used for training includes three key components:
# * Patient Symptoms: Text-based descriptions of medical issues
# * Diseases: Diagnosed medical conditions
# * Medications: Prescribed treatments for each condition
#
# The model architecture consists of an embedding layer for text representation, followed by an LSTM layer for sequence learning. The learned features are then passed to two separate dense output layers—one for disease classification and another for medication recommendation. This multi-output approach allows the system to provide complete diagnostic assistance in a single prediction.
#
# Overall, this project demonstrates the practical application of Deep Learning and Natural Language Processing in healthcare, showcasing how AI can be leveraged to build efficient and intelligent medical support systems.

# %% [markdown]
# ## Implementation: Medical Diagnosis with LSTM
#
# Building a deep learning model for medical diagnosis requires a large dataset of labeled medical data. The dataset used in this tutorial includes:
#
# * Patient Symptoms: Textual descriptions of the patient's symptoms.
# * Diagnoses: The confirmed diseases for each patient.
# * Medications: The prescribed medications for each patient's condition.

# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
from tensorflow.keras.utils import to_categorical
from sklearn.preprocessing import LabelEncoder
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, Embedding, LSTM, Dense

# %% [markdown]
# ## Loading the Dataset

# %%
data = pd.read_csv('medical_data.csv')
data.head()
# Out:
#                                      Patient_Problem  \
# 0  Constant fatigue and muscle weakness, struggli...
# 1  Frequent severe migraines, sensitivity to ligh...
# 2  Sudden weight gain and feeling cold, especiall...
# 3  High fever, sore throat, and swollen lymph nod...
# 4  Excessive thirst and frequent urination, dry m...
#
#                     Disease                                       Prescription
# 0  Chronic Fatigue Syndrome  Cognitive behavioral therapy, graded exercise ...
# 1        Migraine with Aura  Prescription triptans, avoid triggers like bri...
# 2            Hypothyroidism  Levothyroxine to regulate thyroid hormone levels.
# 3             Mononucleosis            Rest and hydration, ibuprofen for pain.
# 4         Diabetes Mellitus             Insulin therapy and lifestyle changes.

# %% [markdown]
# ## Data Preprocessing and Preparation
#
# Before using medical data in a deep learning model, it needs to be preprocessed to ensure the model can understand it. Preprocessing steps often include:
#
# * **Text Tokenization**: Converting textual data into sequences of numbers that the model can process.
# * **Padding Sequences**: Making all sequences the same length by adding padding characters at the beginning or end of shorter sequences.
# * **Label Encoding**: Converting categorical variables, such as disease names and medication names, into numerical labels.

# %% [markdown]
# ### Tokenizing and Sequencing Text Data
#
# A 'tokenizer' variable is created to convert the textual data into sequences of integers. It only considers the top 5,000 words in the dataset in order to reduce the complexity. If the model encounters any out-of-vocabulary words during the training process then it will be replaced with the < OOV > token.

# %%
tokenizer = Tokenizer(num_words=5000, oov_token="<OOV>")
tokenizer.fit_on_texts(data['Patient_Problem'])

sequences = tokenizer.texts_to_sequences(data['Patient_Problem'])

# %% [markdown]
# ### Padding Sequences
#
# In order to make the input sequences have the same length, the code finds the longest sequence and pads all other sequences with zeros at the end ('post' padding) to match this sentence.

# %%
max_length = max(len(x) for x in sequences)
padded_sequences = pad_sequences(sequences, maxlen=max_length, padding='post')

# %% [markdown]
# ### Encoding the Labels and Converting them to Categorical
#
# We will encode the 'Disease' and 'Prescription' columns as integers. Then the integer-encoded labels are converted into binary class matrices.

# %%
# Encoding the labels
label_encoder_disease = LabelEncoder()
label_encoder_prescription = LabelEncoder()

disease_labels = label_encoder_disease.fit_transform(data['Disease'])
prescription_labels = label_encoder_prescription.fit_transform(data['Prescription'])

# Converting labels to categorical
disease_labels_categorical = to_categorical(disease_labels)
prescription_labels_categorical = to_categorical(prescription_labels)

# %% [markdown]
# ### Combining Labels into a Multi-label Target Variable
#
# Finally, now we will stack the binary class matrices together to form a single multi-label target variable 'Y'. This allows the model to predict both 'Disease' and 'Prescription' from the patient's problem.

# %%
Y = np.hstack((disease_labels_categorical, prescription_labels_categorical))

# %% [markdown]
# ## Model Building - LSTM Model
#
# Now, we will build the model using the LSTM and Sequential algorithm from TensorFlow. This model will learn from our preprocessed dataset to predict diseases based on patient symptoms.
#
# ### Defining Model Architecture
#
# We will use the 'Model' and 'Input' to define the model architecture, and 'Embedding' to convert the integer sequences into dense vectors of fixed size. We will use 'Dense' for output layers that make predictions.

# %%
input_layer = Input(shape=(max_length,))

embedding = Embedding(input_dim=5000, output_dim=64)(input_layer)
lstm_layer = LSTM(64)(embedding)

disease_output = Dense(len(label_encoder_disease.classes_), activation='softmax',
name='disease_output')(lstm_layer)

prescription_output = Dense(len(label_encoder_prescription.classes_),
activation='softmax', name='prescription_output')(lstm_layer)

# %% [markdown]
# The model firstly have, an input layer that can handle sequences up to a certain length. Then there's an embedding layer that turns the numbers into vectors. After that, there's an LSTM layer that looks at the order of things, and finally, two dense layers that predict diseases and prescriptions using a softmax function for classification.

# %% [markdown]
# ### Compiling the model

# %%
model = Model(inputs=input_layer, outputs=[disease_output, prescription_output])

model.compile(
    loss={'disease_output': 'categorical_crossentropy',
    'prescription_output': 'categorical_crossentropy'},
    optimizer='adam',
    metrics={'disease_output': ['accuracy'], 'prescription_output': ['accuracy']}
)

model.summary()
# Out:
# Model: "functional_1"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_1       │ (None, 17)        │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ embedding_1         │ (None, 17, 64)    │    320,000 │ input_layer_1[0]… │
# │ (Embedding)         │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ lstm_1 (LSTM)       │ (None, 64)        │     33,024 │ embedding_1[0][0] │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ disease_output      │ (None, 178)       │     11,570 │ lstm_1[0][0]      │
# │ (Dense)             │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ prescription_output │ (None, 388)       │     25,220 │ lstm_1[0][0]      │
# │ (Dense)             │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 389,814 (1.49 MB)
#  Trainable params: 389,814 (1.49 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# ### Training the model

# %%
model.fit(
    padded_sequences,
    {
        'disease_output': disease_labels_categorical,
        'prescription_output': prescription_labels_categorical
    },
    epochs=100,
    batch_size=32,
)
# Out:
# Epoch 1/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step - disease_output_accuracy: 0.0147 - disease_output_loss: 5.1774 - loss: 11.1441 - prescription_output_accuracy: 0.0000e+00 - prescription_output_loss: 5.9666
# Epoch 2/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.0319 - disease_output_loss: 5.1511 - loss: 11.1157 - prescription_output_accuracy: 0.0025 - prescription_output_loss: 5.9645
# Epoch 3/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.0319 - disease_output_loss: 5.0521 - loss: 11.0353 - prescription_output_accuracy: 0.0025 - prescription_output_loss: 5.9842
# Epoch 4/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.0319 - disease_output_loss: 4.9375 - loss: 10.9223 - prescription_output_accuracy: 0.0147 - prescription_output_loss: 5.9841
# Epoch 5/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - disease_output_accuracy: 0.0246 - disease_output_loss: 4.8730 - loss: 10.8208 - prescription_output_accuracy: 0.0147 - prescription_output_loss: 5.9467
# Epoch 6/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.0295 - disease_output_loss: 4.7663 - loss: 10.6698 - prescription_output_accuracy: 0.0221 - prescription_output_loss: 5.9032
# Epoch 7/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.0369 - disease_output_loss: 4.6712 - loss: 10.5181 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.8485
# Epoch 8/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.0393 - disease_output_loss: 4.5872 - loss: 10.3609 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.7752
# Epoch 9/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - disease_output_accuracy: 0.0295 - disease_output_loss: 4.5129 - loss: 10.2333 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.7143
# Epoch 10/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - disease_output_accuracy: 0.0369 - disease_output_loss: 4.4678 - loss: 10.1126 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.6447
# Epoch 11/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.0344 - disease_output_loss: 4.4045 - loss: 9.9913 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.5898
# Epoch 12/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.0516 - disease_output_loss: 4.3342 - loss: 9.8619 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.5242
# Epoch 13/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.0614 - disease_output_loss: 4.2553 - loss: 9.7214 - prescription_output_accuracy: 0.0172 - prescription_output_loss: 5.4643
# Epoch 14/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.0639 - disease_output_loss: 4.1794 - loss: 9.5735 - prescription_output_accuracy: 0.0197 - prescription_output_loss: 5.3893
# Epoch 15/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.0614 - disease_output_loss: 4.1084 - loss: 9.4421 - prescription_output_accuracy: 0.0197 - prescription_output_loss: 5.3338
# Epoch 16/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - disease_output_accuracy: 0.0737 - disease_output_loss: 4.0171 - loss: 9.2764 - prescription_output_accuracy: 0.0197 - prescription_output_loss: 5.2595
# Epoch 17/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 24ms/step - disease_output_accuracy: 0.0909 - disease_output_loss: 3.9564 - loss: 9.1201 - prescription_output_accuracy: 0.0246 - prescription_output_loss: 5.1745
# Epoch 18/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - disease_output_accuracy: 0.0860 - disease_output_loss: 3.8731 - loss: 8.9862 - prescription_output_accuracy: 0.0295 - prescription_output_loss: 5.1093
# Epoch 19/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 28ms/step - disease_output_accuracy: 0.0885 - disease_output_loss: 3.8300 - loss: 8.8822 - prescription_output_accuracy: 0.0319 - prescription_output_loss: 5.0494
# Epoch 20/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - disease_output_accuracy: 0.1057 - disease_output_loss: 3.7541 - loss: 8.7363 - prescription_output_accuracy: 0.0295 - prescription_output_loss: 4.9886
# Epoch 21/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - disease_output_accuracy: 0.0762 - disease_output_loss: 3.7331 - loss: 8.6450 - prescription_output_accuracy: 0.0369 - prescription_output_loss: 4.9195
# Epoch 22/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.1032 - disease_output_loss: 3.6939 - loss: 8.5426 - prescription_output_accuracy: 0.0369 - prescription_output_loss: 4.8644
# Epoch 23/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.1057 - disease_output_loss: 3.6156 - loss: 8.4340 - prescription_output_accuracy: 0.0467 - prescription_output_loss: 4.8154
# Epoch 24/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.1179 - disease_output_loss: 3.5603 - loss: 8.3077 - prescription_output_accuracy: 0.0418 - prescription_output_loss: 4.7495
# Epoch 25/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - disease_output_accuracy: 0.1253 - disease_output_loss: 3.5096 - loss: 8.2102 - prescription_output_accuracy: 0.0442 - prescription_output_loss: 4.6997
# Epoch 26/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - disease_output_accuracy: 0.1229 - disease_output_loss: 3.4733 - loss: 8.1129 - prescription_output_accuracy: 0.0491 - prescription_output_loss: 4.6402
# Epoch 27/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.1572 - disease_output_loss: 3.4223 - loss: 8.0153 - prescription_output_accuracy: 0.0418 - prescription_output_loss: 4.5976
# Epoch 28/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.1450 - disease_output_loss: 3.3936 - loss: 7.9475 - prescription_output_accuracy: 0.0516 - prescription_output_loss: 4.5529
# Epoch 29/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - disease_output_accuracy: 0.1450 - disease_output_loss: 3.3674 - loss: 7.8752 - prescription_output_accuracy: 0.0516 - prescription_output_loss: 4.5125
# Epoch 30/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - disease_output_accuracy: 0.1671 - disease_output_loss: 3.3417 - loss: 7.8232 - prescription_output_accuracy: 0.0565 - prescription_output_loss: 4.4852
# Epoch 31/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - disease_output_accuracy: 0.1867 - disease_output_loss: 3.2956 - loss: 7.7369 - prescription_output_accuracy: 0.0565 - prescription_output_loss: 4.4393
# Epoch 32/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 24ms/step - disease_output_accuracy: 0.1622 - disease_output_loss: 3.2669 - loss: 7.6733 - prescription_output_accuracy: 0.0614 - prescription_output_loss: 4.4042
# Epoch 33/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.1646 - disease_output_loss: 3.2470 - loss: 7.6369 - prescription_output_accuracy: 0.0565 - prescription_output_loss: 4.3874
# Epoch 34/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.1769 - disease_output_loss: 3.2025 - loss: 7.5442 - prescription_output_accuracy: 0.0590 - prescription_output_loss: 4.3396
# Epoch 35/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2064 - disease_output_loss: 3.1487 - loss: 7.4494 - prescription_output_accuracy: 0.0688 - prescription_output_loss: 4.2971
# Epoch 36/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 27ms/step - disease_output_accuracy: 0.1843 - disease_output_loss: 3.1549 - loss: 7.4184 - prescription_output_accuracy: 0.0639 - prescription_output_loss: 4.2759
# Epoch 37/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - disease_output_accuracy: 0.1818 - disease_output_loss: 3.1158 - loss: 7.3602 - prescription_output_accuracy: 0.0713 - prescription_output_loss: 4.2456
# Epoch 38/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - disease_output_accuracy: 0.1867 - disease_output_loss: 3.1202 - loss: 7.3834 - prescription_output_accuracy: 0.0614 - prescription_output_loss: 4.2587
# Epoch 39/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - disease_output_accuracy: 0.1916 - disease_output_loss: 3.1144 - loss: 7.3667 - prescription_output_accuracy: 0.0737 - prescription_output_loss: 4.2458
# Epoch 40/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.1990 - disease_output_loss: 3.0444 - loss: 7.2142 - prescription_output_accuracy: 0.0860 - prescription_output_loss: 4.1682
# Epoch 41/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.2211 - disease_output_loss: 3.0015 - loss: 7.1394 - prescription_output_accuracy: 0.0860 - prescription_output_loss: 4.1326
# Epoch 42/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2408 - disease_output_loss: 2.9446 - loss: 7.0217 - prescription_output_accuracy: 0.1007 - prescription_output_loss: 4.0731
# Epoch 43/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2310 - disease_output_loss: 2.9514 - loss: 7.0025 - prescription_output_accuracy: 0.0934 - prescription_output_loss: 4.0608
# Epoch 44/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.2187 - disease_output_loss: 2.9498 - loss: 7.0026 - prescription_output_accuracy: 0.1007 - prescription_output_loss: 4.0537
# Epoch 45/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.2359 - disease_output_loss: 2.9123 - loss: 6.9352 - prescription_output_accuracy: 0.1106 - prescription_output_loss: 4.0263
# Epoch 46/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2260 - disease_output_loss: 2.9214 - loss: 6.9386 - prescription_output_accuracy: 0.0983 - prescription_output_loss: 4.0283
# Epoch 47/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.2236 - disease_output_loss: 2.8684 - loss: 6.8468 - prescription_output_accuracy: 0.1106 - prescription_output_loss: 3.9757
# Epoch 48/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.2236 - disease_output_loss: 2.8664 - loss: 6.8329 - prescription_output_accuracy: 0.0983 - prescription_output_loss: 3.9754
# Epoch 49/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.2187 - disease_output_loss: 2.8229 - loss: 6.7333 - prescription_output_accuracy: 0.1179 - prescription_output_loss: 3.9114
# Epoch 50/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2506 - disease_output_loss: 2.7622 - loss: 6.6298 - prescription_output_accuracy: 0.1204 - prescription_output_loss: 3.8633
# Epoch 51/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.2678 - disease_output_loss: 2.7211 - loss: 6.5423 - prescription_output_accuracy: 0.1179 - prescription_output_loss: 3.8236
# Epoch 52/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.2506 - disease_output_loss: 2.6709 - loss: 6.4505 - prescription_output_accuracy: 0.1155 - prescription_output_loss: 3.7803
# Epoch 53/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2580 - disease_output_loss: 2.6459 - loss: 6.3997 - prescription_output_accuracy: 0.1376 - prescription_output_loss: 3.7572
# Epoch 54/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.2899 - disease_output_loss: 2.6054 - loss: 6.3157 - prescription_output_accuracy: 0.1400 - prescription_output_loss: 3.7046
# Epoch 55/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - disease_output_accuracy: 0.2899 - disease_output_loss: 2.6099 - loss: 6.3035 - prescription_output_accuracy: 0.1523 - prescription_output_loss: 3.6982
# Epoch 56/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.3096 - disease_output_loss: 2.5602 - loss: 6.2214 - prescription_output_accuracy: 0.1204 - prescription_output_loss: 3.6573
# Epoch 57/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.3096 - disease_output_loss: 2.5379 - loss: 6.1700 - prescription_output_accuracy: 0.1499 - prescription_output_loss: 3.6307
# Epoch 58/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.3170 - disease_output_loss: 2.5144 - loss: 6.1451 - prescription_output_accuracy: 0.1327 - prescription_output_loss: 3.6297
# Epoch 59/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.2899 - disease_output_loss: 2.5524 - loss: 6.1795 - prescription_output_accuracy: 0.1499 - prescription_output_loss: 3.6284
# Epoch 60/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.3292 - disease_output_loss: 2.4940 - loss: 6.0712 - prescription_output_accuracy: 0.1671 - prescription_output_loss: 3.5848
# Epoch 61/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - disease_output_accuracy: 0.3292 - disease_output_loss: 2.4609 - loss: 6.0143 - prescription_output_accuracy: 0.1744 - prescription_output_loss: 3.5556
# Epoch 62/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - disease_output_accuracy: 0.3464 - disease_output_loss: 2.4403 - loss: 5.9565 - prescription_output_accuracy: 0.1695 - prescription_output_loss: 3.5202
# Epoch 63/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.3022 - disease_output_loss: 2.4788 - loss: 6.0206 - prescription_output_accuracy: 0.1400 - prescription_output_loss: 3.5436
# Epoch 64/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.3047 - disease_output_loss: 2.5188 - loss: 6.0887 - prescription_output_accuracy: 0.1744 - prescription_output_loss: 3.5760
# Epoch 65/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - disease_output_accuracy: 0.3243 - disease_output_loss: 2.4976 - loss: 6.0327 - prescription_output_accuracy: 0.1769 - prescription_output_loss: 3.5387
# Epoch 66/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - disease_output_accuracy: 0.3194 - disease_output_loss: 2.4797 - loss: 6.0286 - prescription_output_accuracy: 0.1450 - prescription_output_loss: 3.5485
# Epoch 67/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - disease_output_accuracy: 0.3514 - disease_output_loss: 2.3741 - loss: 5.8484 - prescription_output_accuracy: 0.1671 - prescription_output_loss: 3.4722
# Epoch 68/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.3268 - disease_output_loss: 2.3730 - loss: 5.8204 - prescription_output_accuracy: 0.1548 - prescription_output_loss: 3.4476
# Epoch 69/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.3268 - disease_output_loss: 2.3318 - loss: 5.7087 - prescription_output_accuracy: 0.1843 - prescription_output_loss: 3.3783
# Epoch 70/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.3686 - disease_output_loss: 2.2630 - loss: 5.5996 - prescription_output_accuracy: 0.1843 - prescription_output_loss: 3.3304
# Epoch 71/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.3882 - disease_output_loss: 2.2258 - loss: 5.5051 - prescription_output_accuracy: 0.2359 - prescription_output_loss: 3.2729
# Epoch 72/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.3907 - disease_output_loss: 2.1975 - loss: 5.4526 - prescription_output_accuracy: 0.2457 - prescription_output_loss: 3.2537
# Epoch 73/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.3833 - disease_output_loss: 2.1959 - loss: 5.4531 - prescription_output_accuracy: 0.2334 - prescription_output_loss: 3.2623
# Epoch 74/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.3882 - disease_output_loss: 2.1848 - loss: 5.4206 - prescription_output_accuracy: 0.2310 - prescription_output_loss: 3.2425
# Epoch 75/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.3612 - disease_output_loss: 2.1749 - loss: 5.3738 - prescription_output_accuracy: 0.2260 - prescription_output_loss: 3.2118
# Epoch 76/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - disease_output_accuracy: 0.3857 - disease_output_loss: 2.1566 - loss: 5.3467 - prescription_output_accuracy: 0.2260 - prescription_output_loss: 3.1934
# Epoch 77/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - disease_output_accuracy: 0.3980 - disease_output_loss: 2.1216 - loss: 5.2869 - prescription_output_accuracy: 0.2531 - prescription_output_loss: 3.1640
# Epoch 78/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.4373 - disease_output_loss: 2.0798 - loss: 5.2221 - prescription_output_accuracy: 0.2383 - prescription_output_loss: 3.1356
# Epoch 79/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4079 - disease_output_loss: 2.0676 - loss: 5.1956 - prescription_output_accuracy: 0.2531 - prescription_output_loss: 3.1195
# Epoch 80/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - disease_output_accuracy: 0.4152 - disease_output_loss: 2.0365 - loss: 5.1288 - prescription_output_accuracy: 0.2727 - prescription_output_loss: 3.0985
# Epoch 81/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - disease_output_accuracy: 0.4423 - disease_output_loss: 2.0219 - loss: 5.0877 - prescription_output_accuracy: 0.2703 - prescription_output_loss: 3.0728
# Epoch 82/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 22ms/step - disease_output_accuracy: 0.4251 - disease_output_loss: 2.0258 - loss: 5.1006 - prescription_output_accuracy: 0.2654 - prescription_output_loss: 3.0693
# Epoch 83/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.4373 - disease_output_loss: 2.0517 - loss: 5.1524 - prescription_output_accuracy: 0.2506 - prescription_output_loss: 3.1015
# Epoch 84/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4226 - disease_output_loss: 2.0395 - loss: 5.1203 - prescription_output_accuracy: 0.2482 - prescription_output_loss: 3.0758
# Epoch 85/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.4398 - disease_output_loss: 2.0219 - loss: 5.0572 - prescription_output_accuracy: 0.2580 - prescription_output_loss: 3.0441
# Epoch 86/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4398 - disease_output_loss: 2.0361 - loss: 5.1115 - prescription_output_accuracy: 0.2531 - prescription_output_loss: 3.0796
# Epoch 87/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4152 - disease_output_loss: 2.0644 - loss: 5.1608 - prescription_output_accuracy: 0.2383 - prescription_output_loss: 3.0919
# Epoch 88/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4644 - disease_output_loss: 1.9584 - loss: 4.9537 - prescription_output_accuracy: 0.2678 - prescription_output_loss: 2.9934
# Epoch 89/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4644 - disease_output_loss: 1.9136 - loss: 4.8563 - prescription_output_accuracy: 0.2850 - prescription_output_loss: 2.9370
# Epoch 90/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - disease_output_accuracy: 0.4816 - disease_output_loss: 1.9005 - loss: 4.8178 - prescription_output_accuracy: 0.2973 - prescription_output_loss: 2.9192
# Epoch 91/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.4840 - disease_output_loss: 1.9084 - loss: 4.8652 - prescription_output_accuracy: 0.2801 - prescription_output_loss: 2.9611
# Epoch 92/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4742 - disease_output_loss: 1.9202 - loss: 4.8816 - prescription_output_accuracy: 0.2801 - prescription_output_loss: 2.9590
# Epoch 93/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4644 - disease_output_loss: 1.9487 - loss: 4.9372 - prescription_output_accuracy: 0.2506 - prescription_output_loss: 2.9848
# Epoch 94/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4914 - disease_output_loss: 1.9509 - loss: 4.9179 - prescription_output_accuracy: 0.2334 - prescription_output_loss: 2.9706
# Epoch 95/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4988 - disease_output_loss: 1.8784 - loss: 4.7619 - prescription_output_accuracy: 0.2629 - prescription_output_loss: 2.8916
# Epoch 96/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - disease_output_accuracy: 0.4791 - disease_output_loss: 1.8598 - loss: 4.7066 - prescription_output_accuracy: 0.2776 - prescription_output_loss: 2.8551
# Epoch 97/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - disease_output_accuracy: 0.5086 - disease_output_loss: 1.8384 - loss: 4.6711 - prescription_output_accuracy: 0.2875 - prescription_output_loss: 2.8427
# Epoch 98/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - disease_output_accuracy: 0.5233 - disease_output_loss: 1.8266 - loss: 4.6337 - prescription_output_accuracy: 0.2998 - prescription_output_loss: 2.8140
# Epoch 99/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - disease_output_accuracy: 0.5356 - disease_output_loss: 1.7724 - loss: 4.5615 - prescription_output_accuracy: 0.3145 - prescription_output_loss: 2.7909
# Epoch 100/100
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - disease_output_accuracy: 0.5381 - disease_output_loss: 1.7765 - loss: 4.5623 - prescription_output_accuracy: 0.3366 - prescription_output_loss: 2.7925

# %% [markdown]
# ### Making Predictions
#
# The model is used to make predictions for new patients:
#
# 1. Pre-processed the patient's symptoms by performing tokenization and padding.
# 2. Feed the pre-processed data into the trained model.
# 3. The model predicts the disease and medication based on the patient's symptoms.
# 4. The predicted disease and medication will be presented.

# %%
def make_prediction(patient_problem):
    # Preprocessing the input
    sequence = tokenizer.texts_to_sequences([patient_problem])
    padded_sequence = pad_sequences(sequence, maxlen=max_length, padding='post')

    # Making prediction
    prediction = model.predict(padded_sequence)

    # Decoding the prediction
    disease_index = np.argmax(prediction[0], axis=1)[0]
    prescription_index = np.argmax(prediction[1], axis=1)[0]

    disease_predicted = label_encoder_disease.inverse_transform([disease_index])[0]
    prescription_predicted = label_encoder_prescription.inverse_transform([prescription_index])[0]

    print(f"Predicted Disease: {disease_predicted}")
    print(f"Suggested Prescription: {prescription_predicted}")

# %% [markdown]
# ## Conclusion
#
# Adding deep learning to medical diagnostics is a game-changer in healthcare.The model is trained on the preprocessed dataset, iteratively adjusting its internal parameters to improve its accuracy in predicting diseases and medications based on patient symptoms.

# %%
patient_input = "I've experienced a loss of appetite and don't enjoy food anymore."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 373ms/step
# Predicted Disease: Depression
# Suggested Prescription: Antidepressants; eating nutrient-rich foods.

# %%
patient_input = "I am experiencing stomach pain, bloating, and nausea after eating."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step
# Predicted Disease: Subarachnoid Hemorrhage
# Suggested Prescription: Antidepressants, psychotherapy.

# %%
patient_input = "I have continuous joint pain and stiffness, especially in the morning."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted Disease: Peripheral Neuropathy
# Suggested Prescription: Blood sugar control; pain relievers; capsaicin cream.

# %%
patient_input = "I have difficulty breathing, wheezing, and chest tightness."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 61ms/step
# Predicted Disease: Bronchial Asthma
# Suggested Prescription: Low-salt diet; medication to reduce urine output.

# %%
patient_input = "I have itchy red rashes on my skin that have been spreading."
make_prediction(patient_input)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 66ms/step
# Predicted Disease: Psoriasis
# Suggested Prescription: Topical treatments and light therapy.
